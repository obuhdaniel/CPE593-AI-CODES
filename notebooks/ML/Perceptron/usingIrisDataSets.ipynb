# %%
from sklearn import datasets
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
iris = datasets.load_iris()
df = pd.DataFrame(iris.data, columns= iris.feature_names)
df['target']= iris.target
df['target_name'] = df['target'].map(lambda x: iris.target_names[x])
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target target_name
# 0         0      setosa
# 1         0      setosa
# 2         0      setosa
# 3         0      setosa
# 4         0      setosa
# ..      ...         ...
# 145       2   virginica
# 146       2   virginica
# 147       2   virginica
# 148       2   virginica
# 149       2   virginica
#
# [150 rows x 6 columns]

# %%
#lets drop out the wisth columns as they are not part of our domain
df = df.iloc[:100, [0,2,4,5]]
df
# Out:
#     sepal length (cm)  petal length (cm)  target target_name
# 0                 5.1                1.4       0      setosa
# 1                 4.9                1.4       0      setosa
# 2                 4.7                1.3       0      setosa
# 3                 4.6                1.5       0      setosa
# 4                 5.0                1.4       0      setosa
# ..                ...                ...     ...         ...
# 95                5.7                4.2       1  versicolor
# 96                5.7                4.2       1  versicolor
# 97                6.2                4.3       1  versicolor
# 98                5.1                3.0       1  versicolor
# 99                5.7                4.1       1  versicolor
#
# [100 rows x 4 columns]

# %%
#lets convert the categorical class called target names to either 1 or -1
df['target'] = np.where((df['target_name'] =='setosa'), -1, 1)
df
# Out:
#     sepal length (cm)  petal length (cm)  target target_name
# 0                 5.1                1.4      -1      setosa
# 1                 4.9                1.4      -1      setosa
# 2                 4.7                1.3      -1      setosa
# 3                 4.6                1.5      -1      setosa
# 4                 5.0                1.4      -1      setosa
# ..                ...                ...     ...         ...
# 95                5.7                4.2       1  versicolor
# 96                5.7                4.2       1  versicolor
# 97                6.2                4.3       1  versicolor
# 98                5.1                3.0       1  versicolor
# 99                5.7                4.1       1  versicolor
#
# [100 rows x 4 columns]

# %%
Y = df['target']
Y
X = df.iloc[:,:2].values
X
# Out:
# array([[5.1, 1.4],
#        [4.9, 1.4],
#        [4.7, 1.3],
#        [4.6, 1.5],
#        [5. , 1.4],
#        [5.4, 1.7],
#        [4.6, 1.4],
#        [5. , 1.5],
#        [4.4, 1.4],
#        [4.9, 1.5],
#        [5.4, 1.5],
#        [4.8, 1.6],
#        [4.8, 1.4],
#        [4.3, 1.1],
#        [5.8, 1.2],
#        [5.7, 1.5],
#        [5.4, 1.3],
#        [5.1, 1.4],
#        [5.7, 1.7],
#        [5.1, 1.5],
#        [5.4, 1.7],
#        [5.1, 1.5],
#        [4.6, 1. ],
#        [5.1, 1.7],
#        [4.8, 1.9],
#        [5. , 1.6],
#        [5. , 1.6],
#        [5.2, 1.5],
#        [5.2, 1.4],
#        [4.7, 1.6],
#        [4.8, 1.6],
#        [5.4, 1.5],
#        [5.2, 1.5],
#        [5.5, 1.4],
#        [4.9, 1.5],
#        [5. , 1.2],
#        [5.5, 1.3],
#        [4.9, 1.4],
#        [4.4, 1.3],
#        [5.1, 1.5],
#        [5. , 1.3],
#        [4.5, 1.3],
#        [4.4, 1.3],
#        [5. , 1.6],
#        [5.1, 1.9],
#        [4.8, 1.4],
#        [5.1, 1.6],
#        [4.6, 1.4],
#        [5.3, 1.5],
#        [5. , 1.4],
#        [7. , 4.7],
#        [6.4, 4.5],
#        [6.9, 4.9],
#        [5.5, 4. ],
#        [6.5, 4.6],
#        [5.7, 4.5],
#        [6.3, 4.7],
#        [4.9, 3.3],
#        [6.6, 4.6],
#        [5.2, 3.9],
#        [5. , 3.5],
#        [5.9, 4.2],
#        [6. , 4. ],
#        [6.1, 4.7],
#        [5.6, 3.6],
#        [6.7, 4.4],
#        [5.6, 4.5],
#        [5.8, 4.1],
#        [6.2, 4.5],
#        [5.6, 3.9],
#        [5.9, 4.8],
#        [6.1, 4. ],
#        [6.3, 4.9],
#        [6.1, 4.7],
#        [6.4, 4.3],
#        [6.6, 4.4],
#        [6.8, 4.8],
#        [6.7, 5. ],
#        [6. , 4.5],
#        [5.7, 3.5],
#        [5.5, 3.8],
#        [5.5, 3.7],
#        [5.8, 3.9],
#        [6. , 5.1],
#        [5.4, 4.5],
#        [6. , 4.5],
#        [6.7, 4.7],
#        [6.3, 4.4],
#        [5.6, 4.1],
#        [5.5, 4. ],
#        [5.5, 4.4],
#        [6.1, 4.6],
#        [5.8, 4. ],
#        [5. , 3.3],
#        [5.6, 4.2],
#        [5.7, 4.2],
#        [5.7, 4.2],
#        [6.2, 4.3],
#        [5.1, 3. ],
#        [5.7, 4.1]])

# %%
plt.figure(figsize=(8,6))
plt.scatter(X[:50, 0], X[:50, 1], marker='o', label='setosa(-1)', color='red')
plt.scatter(X[50:100, 0], X[50:100, 1], marker='x', label='versicolor(1)', color='blue')
plt.xlabel('sepal length(cm)')
plt.ylabel('petal lenght(cm)')
plt.plot()
plt.show()
